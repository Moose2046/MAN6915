# %%
import pandas as pd
import numpy as np
from sklearn import linear_model, datasets
from sklearn.cross_validation import train_test_split

# %%
df = pd.read_csv('Comma Data Updated Headers.csv')

# %%
df
# Out:
#       RespondentID                                           Sentence  \
# 0       3292953864  It's important for a person to be honest, kind...
# 1       3292950324  It's important for a person to be honest, kind...
# 2       3292942669  It's important for a person to be honest, kind...
# 3       3292932796  It's important for a person to be honest, kind...
# 5       3292926586  It's important for a person to be honest, kind...
# 6       3292908135  It's important for a person to be honest, kind...
# 7       3292869879  It's important for a person to be honest, kind...
# 8       3292863455  It's important for a person to be honest, kind...
# 9       3292860428  It's important for a person to be honest, kind...
# 10      3292753795  It's important for a person to be honest, kind...
# 11      3292742681  It's important for a person to be honest, kind...
# 12      3292735069  It's important for a person to be honest, kind...
# ...

# %%
df = df.dropna(subset = ['Gender', 'Age'])
series = df.groupby(["Gender", "Age",]).transform(lambda x: x.fillna(x.value_counts().index[0]))
series
#   ["Income"].count()
# series
# df.groupby(["Gender", "Age", "Income"]).agg(lambda x:x.value_counts().index[0])
# type(series)
# df.groupby(["Gender", "Age", "Income"])["Income"].value_counts().index[0]
# for i, row in series.iteritems():
#     print(i, row)
# pd.get_dummies(df, drop_first= True)
# df2
# df.iloc[df.groupby(["Gender", "Age", "Income"])['Income'].count
# Out:
#       RespondentID                                           Sentence  \
# 0       3292953864  It's important for a person to be honest, kind...
# 1       3292950324  It's important for a person to be honest, kind...
# 2       3292942669  It's important for a person to be honest, kind...
# 3       3292932796  It's important for a person to be honest, kind...
# 5       3292926586  It's important for a person to be honest, kind...
# 6       3292908135  It's important for a person to be honest, kind...
# 7       3292869879  It's important for a person to be honest, kind...
# 8       3292863455  It's important for a person to be honest, kind...
# 9       3292860428  It's important for a person to be honest, kind...
# 10      3292753795  It's important for a person to be honest, kind...
# 11      3292742681  It's important for a person to be honest, kind...
# 12      3292735069  It's important for a person to be honest, kind...
# ...

# %%
series
# Out:
#       RespondentID                                           Sentence  \
# 0       3292953864  It's important for a person to be honest, kind...
# 1       3292950324  It's important for a person to be honest, kind...
# 2       3292942669  It's important for a person to be honest, kind...
# 3       3292932796  It's important for a person to be honest, kind...
# 5       3292926586  It's important for a person to be honest, kind...
# 6       3292908135  It's important for a person to be honest, kind...
# 7       3292869879  It's important for a person to be honest, kind...
# 8       3292863455  It's important for a person to be honest, kind...
# 9       3292860428  It's important for a person to be honest, kind...
# 10      3292753795  It's important for a person to be honest, kind...
# 11      3292742681  It's important for a person to be honest, kind...
# 12      3292735069  It's important for a person to be honest, kind...
# ...

# %%
df2 = df.dropna()
df3 = pd.get_dummies(df2, drop_first= True)
# df3.to_csv('Test2.csv')
df3.head()
df3.to_csv('clean_data.csv')
y = df3["Sentence_It's important for a person to be honest, kind, and loyal."]
x = df3.drop(["Sentence_It's important for a person to be honest, kind, and loyal.", "RespondentID"], axis=1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = .2, random_state=42, stratify=y)
