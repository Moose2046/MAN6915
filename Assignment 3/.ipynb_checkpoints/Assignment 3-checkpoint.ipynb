# %% [markdown]
# Homework Assignment 3
# 1.  Read iris.txt into a data frame (2 point)
# 2.	Explore the data
#     1.	Print the head the dataset (2 point)
#     2.	Print the tail of the dataset (2 point)
#     3.	Print summary statistics for the data frame (both numeric and categorical columns) (2 point)
#     4.	Generate a box plot for the data set (2 point)
#     5.	Generate a line plot the dataset (2 point)
#     6.	Generate a histogram of the dataset (2 point)
# 3.	Group the data on the Species column and explore the partitioned dataset
#     1.	Print the summary statistics for each species in the dataset (2 point)
#     2.	Generate a boxplot for each species in the dataset (2 point)
#     3.	Generate a scatter matrix for the dataset (2 point)
# 4.	Provide an answer to the analysis question based on your interpretation of the data (2 point)

# %%
import pandas as pd
from pandas.tools.plotting import scatter_matrix
# %matplotlib inline

# %% [markdown]
# ### Q1
# Read iris.txt into a data frame

# %%
#Reads in the data
df = pd.read_csv('iris.txt')

# %%
#Prints the type of each object 
df.dtypes
# Out:
# SepalLength    float64
# SepalWidth     float64
# PetalLength    float64
# PetalWidth     float64
# Species         object
# dtype: object

# %% [markdown]
# Most of the items are floats and single varaible is an object

# %% [markdown]
# ### Q2.1
# Print the head the dataset

# %%
df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth      Species
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %% [markdown]
# Checks the first 5 rows of the dataset. Seems like the Species columns is a string with the type of flower. Most of the data is numerical, one field is categorical, and seems like it identifies each species

# %% [markdown]
# ### Q2.2
# Print the tail of the dataset

# %%
df.tail()
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth         Species
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica

# %% [markdown]
# There seems to be 150 rows of data 0-149.

# %% [markdown]
# ### Q2.3
# Print summary statistics for the data frame

# %%
#Describes Data
df.describe(include='all')
# Out:
#         SepalLength  SepalWidth  PetalLength  PetalWidth      Species
# count    150.000000  150.000000   150.000000  150.000000          150
# unique          NaN         NaN          NaN         NaN            3
# top             NaN         NaN          NaN         NaN  Iris-setosa
# freq            NaN         NaN          NaN         NaN           50
# mean       5.843333    3.054000     3.758667    1.198667          NaN
# std        0.828066    0.433594     1.764420    0.763161          NaN
# min        4.300000    2.000000     1.000000    0.100000          NaN
# 25%        5.100000    2.800000     1.600000    0.300000          NaN
# 50%        5.800000    3.000000     4.350000    1.300000          NaN
# 75%        6.400000    3.300000     5.100000    1.800000          NaN
# max        7.900000    4.400000     6.900000    2.500000          NaN

# %% [markdown]
# Describe by default only runs on numeric data, so we had to include='all'
#
# It seems like sepal is much larger than the petal in general.
#
# PetalWidth is the smallest.
#
# The petal lenght has the largest standard deviation.
#
# There are 3 unique flower types. The first alphabetical flower is Iris-setosa, and there are 50 rows of data.

# %% [markdown]
# ### Q2.4
# Generate a box plot for the data set

# %%
#Standard Box plot fo teh entire dataset
df.plot.box()

# %% [markdown]
# PetalLenght has the largest variance.
#
# SepalLength is generally the longest.
#
# PetalWidth is generally the shorest.
#
# SepalWidth has a very small variance.
#
# Each of the boxes above reprsesents 25% to 75% of the data for each of the variables.

# %% [markdown]
# PetalLength is the variable has varies to most. While Sepal Width has the most narrow rage.sepalLength is generally the logesnt and PetalWidth is the shortest

# %% [markdown]
# ### Q2.5

# %%
df.plot.line()

# %% [markdown]
# Like the box plot above it seems like the widest range of variables would be the Petal Lenght. It also seem like this might be an option to predict the type of flower since there are major jumps. Those jumps also seemed to be matched by the petalwidth.

# %% [markdown]
# ### Q2.6

# %%
df.plot.hist()

# %% [markdown]
# Each of the columns seems to live in it's own area. Meaning that all of PetalWidth are closely related together. There are only in the first 4 buckets, and it doesn't show again in later buckets.

# %% [markdown]
# ### Q3.1

# %%
df.groupby('Species').describe()
# Out:
#                        PetalLength  PetalWidth  SepalLength  SepalWidth
# Species
# Iris-setosa     count    50.000000   50.000000    50.000000   50.000000
#                 mean      1.464000    0.244000     5.006000    3.418000
#                 std       0.173511    0.107210     0.352490    0.381024
#                 min       1.000000    0.100000     4.300000    2.300000
#                 25%       1.400000    0.200000     4.800000    3.125000
#                 50%       1.500000    0.200000     5.000000    3.400000
#                 75%       1.575000    0.300000     5.200000    3.675000
#                 max       1.900000    0.600000     5.800000    4.400000
# Iris-versicolor count    50.000000   50.000000    50.000000   50.000000
#                 mean      4.260000    1.326000     5.936000    2.770000
#                 std       0.469911    0.197753     0.516171    0.313798
#                 min       3.000000    1.000000     4.900000    2.000000
# ...

# %% [markdown]
# Nothing seems to stand out here it. After using the graphs going back to the data in this instance doesn't seem to help much.

# %% [markdown]
# ### Q3.2

# %%
for (method, group) in df.groupby('Species'):
    group.plot.box(title= method)

# %% [markdown]
# From the above graph, it seems like the SepalLength and Width, are about the same for each type of flower. The Petal length on the other seems to have more variation, but not enough for us to clearly identify what type of flower by itself. Petal Width might be able to help overcome some of that gap

# %% [markdown]
# ### Q3.3

# %%
scatter_matrix(df, figsize=(8, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000ADCAE80>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000B943400>]], dtype=object)

# %% [markdown]
# The above chart shows how each numeric variable relates to each other, and a histogram when a variable is related to itself. SepalWidth has the most normal curve of the variables. There is also gaps in all the comparisons vs petallength. Leading me to believe that you can use PetalLength with other variables to help predict the variable.

# %% [markdown]
# ### Q4

# %% [markdown]
# Provide an answer to the analysis question based on your interpretation of the data:
#
# It seems like PetalLength is a primary indicator in trying to predict the species of flower, but to increase our prediction rate, we should also look at other things. Things like PetalWidth, and the relationship between variables can be used improve prediction accuracy.
